# %%
import pandas as pd, time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
options = Options()
options.add_argument("--headless=new")
#Extract Tribridges tournament info: Date, time, title, and eventually sections and time control
browser = webdriver.Chrome(options=options)
browser.get('https://tribridgeschessclub.com/events/category/tournaments/')
time.sleep(0.5)
date_elements = browser.find_elements(By.CLASS_NAME, 'tribe-events-calendar-list__event-datetime-wrapper')
date_texts = []
for elem in date_elements:
    date_texts.append(elem.text)
    time.sleep(0.5)
link_elements = browser.find_elements(By.CLASS_NAME, 'tribe-events-calendar-list__event-title-link')
link_texts = []
link_hrefs = []
for elem in link_elements:
    link_texts.append(elem.text)
    link_hrefs.append(elem.get_attribute("href"))
cost_texts = []
desc_texts = []
for link in link_hrefs:
    browser.get(link)
    time.sleep(0.5)
    cost_elements = browser.find_elements(By.CLASS_NAME, 'tribe-events-cost')
    for cost in cost_elements:
        cost_texts.append(cost.text)
    description_elements = browser.find_elements(By.CLASS_NAME, "tribe-events-single-event-description")
    for desc in description_elements:
        desc_texts.append(desc.text)

section_texts = []
time_texts = []
for desc in desc_texts:
    lines = desc.split("\n")
    sections = None
    time_control = None
    for line in lines:
        if "Sections:" in line:
            sections = line.replace("Sections:", "")
            section_texts.append(sections)
        if "Time Control:" in line:
            time_control = line.replace("Time Control:", "")
            time_texts.append(time_control)
    if sections == None:
        section_texts.append("Not Found")
    if time_control == None:
        time_texts.append("Not Found")
df = pd.DataFrame(data = {"Tournament Titles": link_texts, 'Dates': date_texts, "Links": link_hrefs, "Cost": cost_texts, "Description": desc_texts, "Sections": section_texts, "Time Control": time_texts})

for i in range(len(link_texts)):
    print("TITLE: " + df.iloc[i, 0])
    print("LINK: " + df.iloc[i, 2])
    print("DATE AND TIME: " + df.iloc[i, 1])
    print("SECTIONS: " + df.iloc[i, 5])
    print("TIME CONTROL: " + df.iloc[i, 6])
    print("COST: " + df.iloc[i, 3])
    print("DESCRIPTION:\n" + df.iloc[i, 4])
    print("\n")
# Out:
# 12 12 12 7 12 12 12
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 53
#      49         section_texts.append("Not Found")
#      50     if time_control == None:
#      51         time_texts.append("Not Found")
#      52 print(len(link_texts), len(date_texts), len(link_hrefs), len(cost_texts), len(desc_texts), len(section_texts), len(time_texts))
# ---> 53 df = pd.DataFrame(data = {"Tournament Titles": link_texts, 'Dates': date_texts, "Links": link_hrefs, "Cost": cost_texts, "Description": desc_texts, "Sections": section_texts, "Time Control": time_texts})
#      54
#      55 for i in range(len(link_texts)):
#      56     print("TITLE: " + df.iloc[i, 0])
#
# File c:\Users\yasme\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:769, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     765             )
#     766
#     767         elif isinstance(data, dict):
#     768             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 769             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy)
#     770         elif isinstance(data, ma.MaskedArray):
#     771             from numpy.ma import mrecords
#     772
#
# File c:\Users\yasme\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\construction.py:460, in dict_to_mgr(data, index, columns, dtype, copy)
#     441 if copy:
#     442     # We only need to copy arrays that will not get consolidated, i.e.
#     443     #  only EA arrays
#     444     arrays = [
#     445         (
#     446             x.copy()
#    (...)    457         for x in arrays
#     458     ]
# --> 460 return arrays_to_mgr(arrays, columns, index, dtype=dtype, consolidate=copy)
#
# File c:\Users\yasme\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\construction.py:113, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, consolidate)
#     110 if verify_integrity:
#     111     # figure out the index, if necessary
#     112     if index is None:
# --> 113         index = _extract_index(arrays)
#     114     else:
#     115         index = ensure_index(index)
#
# File c:\Users\yasme\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\construction.py:643, in _extract_index(data)
#     641 if have_raw_arrays:
#     642     if len(raw_lengths) > 1:
# --> 643         raise ValueError("All arrays must be of the same length")
#     645     if have_dicts:
#     646         raise ValueError(
#     647             "Mixing dicts with non-Series may lead to ambiguous ordering."
#     648         )
#
# ValueError: All arrays must be of the same length
